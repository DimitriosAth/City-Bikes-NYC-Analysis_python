# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import folium
import json

# %%
# This command propts matplotlib visuals to appear in the notebook 

# %matplotlib inline

# %%
path=r'/Users/Dimitris/Desktop/CF Data Analytics/Data Immersion/Achievement 6/02 Data'

# %%
# Import the “df_sub.pkl” file into Jupyter as df_sub

df_sub = pd.read_pickle(os.path.join(path, 'Prepared Data', 'df_sub.pkl'))

# %%
# Import ".json" file for the U.S. as geo_d

geo_d = r'/Users/Dimitris/Desktop/CF Data Analytics/Data Immersion/Achievement 6/02 Data/Original Data/custom.geo.json'

# %%
# View the JSON file contents

f = open(r'/Users/Dimitris/Desktop/CF Data Analytics/Data Immersion/Achievement 6/02 Data/Original Data/custom.geo.json',)
  
# returns JSON object asa dictionary
data = json.load(f)
  
# Iterating through the json list
for i in data['features']:
    print(i)
# Out:
# {'type': 'Feature', 'properties': {'featurecla': 'Admin-0 country', 'scalerank': 1, 'labelrank': 5, 'sovereignt': 'Costa Rica', 'sov_a3': 'CRI', 'adm0_dif': 0, 'level': 2, 'type': 'Sovereign country', 'tlc': '1', 'admin': 'Costa Rica', 'adm0_a3': 'CRI', 'geou_dif': 0, 'geounit': 'Costa Rica', 'gu_a3': 'CRI', 'su_dif': 0, 'subunit': 'Costa Rica', 'su_a3': 'CRI', 'brk_diff': 0, 'name': 'Costa Rica', 'name_long': 'Costa Rica', 'brk_a3': 'CRI', 'brk_name': 'Costa Rica', 'brk_group': None, 'abbrev': 'C.R.', 'postal': 'CR', 'formal_en': 'Republic of Costa Rica', 'formal_fr': None, 'name_ciawf': 'Costa Rica', 'note_adm0': None, 'note_brk': None, 'name_sort': 'Costa Rica', 'name_alt': None, 'mapcolor7': 3, 'mapcolor8': 2, 'mapcolor9': 4, 'mapcolor13': 2, 'pop_est': 5047561, 'pop_rank': 13, 'pop_year': 2019, 'gdp_md': 61801, 'gdp_year': 2019, 'economy': '5. Emerging region: G20', 'income_grp': '3. Upper middle income', 'fips_10': 'CS', 'iso_a2': 'CR', 'iso_a2_eh': 'CR', 'iso_a3': 'CRI', 'iso_
# ...

# %%
df_sub.shape
# Out:
# (12570179, 21)

# %%
df_sub.dtypes
# Out:
# trip_duration                     float64
# start_time                 datetime64[ns]
# stop_time                  datetime64[ns]
# start_station_id                  float64
# start_station_name                 object
# start_station_latitude            float64
# start_station_longitude           float64
# end_station_id                    float64
# end_station_name                   object
# end_station_latitude              float64
# end_station_longitude             float64
# bike_id                             int64
# user_type                          object
# birth_year                        float64
# gender                             object
# age                               float64
# age_group_loc                      object
# trip_duration_range_loc            object
# station_users                      object
# day_of_week                        object
# hour_of_day                         int64
# dtype: object

# %%
# df_sub trip_duration outliers

green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Trip duration')
ax3.boxplot(df_sub.trip_duration, flierprops=green_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa5e1851160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fa5e1851730>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa5e1851c40>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa4e6408520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa4e64087f0>],
#  'means': []}

# %%
sns.histplot(df_sub['trip_duration'], bins=20, kde = True)
# Out:
# <AxesSubplot:xlabel='trip_duration', ylabel='Count'>

# %%
# Change coordinate columns' data types to string

df_sub['start_station_latitude'] = df_sub['start_station_latitude'].astype(str)
df_sub['end_station_latitude'] = df_sub['end_station_latitude'].astype(str)
df_sub['start_station_longitude'] = df_sub['start_station_longitude'].astype(str)
df_sub['end_station_longitude'] = df_sub['end_station_longitude'].astype(str)

# %%
df_sub.dtypes
# Out:
# trip_duration                     float64
# start_time                 datetime64[ns]
# stop_time                  datetime64[ns]
# start_station_id                  float64
# start_station_name                 object
# start_station_latitude             object
# start_station_longitude            object
# end_station_id                    float64
# end_station_name                   object
# end_station_latitude               object
# end_station_longitude              object
# bike_id                             int64
# user_type                          object
# birth_year                        float64
# gender                             object
# age                               float64
# age_group_loc                      object
# trip_duration_range_loc            object
# station_users                      object
# day_of_week                        object
# hour_of_day                         int64
# dtype: object

# %%
# For the purposes of my analysis I will keep all trips with a duration between 2 minutes and up to 2,900 mins (48.33 hours)
# I will treat the remaining trips as outliers or errors as trips outside these limits are not reasonable for a city rental service.


df_sub2 = df_sub[df_sub['trip_duration'] >= 2]
df_sub2 = df_sub[df_sub['trip_duration'] <= 2900]

# %%
df_sub2
# Out:
#         trip_duration              start_time               stop_time  \
# 0           11.333333 2017-01-01 00:00:21.000 2017-01-01 00:11:41.000
# 4           10.350000 2017-01-01 00:01:25.000 2017-01-01 00:11:47.000
# 8            4.250000 2017-01-01 00:05:47.000 2017-01-01 00:10:02.000
# 12          33.416667 2017-01-01 00:05:57.000 2017-01-01 00:39:23.000
# 16          14.983333 2017-01-01 00:09:20.000 2017-01-01 00:24:19.000
# ...               ...                     ...                     ...
# 955187      22.616667 2019-12-31 23:51:18.276 2020-01-01 00:13:56.184
# 955191       7.850000 2019-12-31 23:52:57.231 2020-01-01 00:00:48.247
# 955195      22.633333 2019-12-31 23:53:18.074 2020-01-01 00:15:56.948
# 955199      29.500000 2019-12-31 23:54:53.088 2020-01-01 00:24:23.209
# 955203    2034.983333 2019-12-31 23:55:30.726 2020-01-02 09:50:30.671
#
#         start_station_id           start_station_name start_station_latitude  \
# ...

# %%
# df_sub2 trip_duration outliers

green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Trip duration')
ax3.boxplot(df_sub2.trip_duration, flierprops=green_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa2a642db20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fa2a6439100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa2a642d850>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa2a64396a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa2a6439970>],
#  'means': []}

# %%
# Count the start stations

df_ssd = df_sub2.groupby(['start_station_name', 'start_station_latitude', 'start_station_longitude'], sort=False, as_index=False).agg(count=('start_station_name', 'count'))

# %%
# Add formal_en column to use as Key for map

df_ssd = pd.DataFrame(df_ssd)
df_ssd["formal_en"] = 'United States of America'

# %%
df_ssd
# Out:
#                start_station_name start_station_latitude  \
# 0     W 82 St & Central Park West               40.78275
# 1                 5 Ave & E 78 St      40.77682863439968
# 2                York St & Jay St             40.7014851
# 3                 W 43 St & 6 Ave            40.75527307
# 4                W 43 St & 10 Ave            40.76009437
# ...                           ...                    ...
# 1209             5 Ave & E 103 St                 40.791
# 1210          W 100 St & Broadway                 40.797
# 1211     Fairview Ave & Linden St               40.70694
# 1212       Wyckoff St & Nevins St              40.683426
# 1213    Irving Ave & Jefferson St                 40.704
#
#      start_station_longitude  count                 formal_en
# 0                  -73.97137  16328  United States of America
# 1         -73.96388769149779    954  United States of America
# 2               -73.98656928   6738  United States of America
# ...

# %%
# Count the end stations

df_esd = df_sub2.groupby(['end_station_name', 'end_station_latitude', 'end_station_longitude'], sort=False, as_index=False).agg(count=('end_station_name', 'count'))

# %%
df_esd = pd.DataFrame(df_esd)
df_esd["formal_en"] = 'United States of America'

# %%
df_esd.head()
# Out:
#               end_station_name end_station_latitude end_station_longitude  \
# 0  Central Park West & W 72 St    40.77579376683666     -73.9762057363987
# 1              3 Ave & E 71 St          40.76873687          -73.96119945
# 2   Carlton Ave & Flushing Ave            40.697787            -73.973736
# 3              E 95 St & 3 Ave           40.7849032            -73.950503
# 4              8 Ave & W 16 St            40.740983            -74.001702
#
#    count                 formal_en
# 0  35334  United States of America
# 1   7169  United States of America
# 2   9264  United States of America
# 3   2485  United States of America
# 4   9757  United States of America

# %%
# Create start_station_map

start_station_map = folium.Map(location = [100, 0], zoom_start = 1.5)

folium.Choropleth(
    geo_data = geo_d, 
    data = df_ssd,
    columns = ['start_station_name', 'count'],
    key_on = 'feature.properties.formal_en',
    fill_color = 'YlOrBr', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "Start station popularity").add_to(start_station_map)
folium.LayerControl().add_to(start_station_map)

# %%
start_station_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Create end_station_map

end_station_map = folium.Map(location = [100, 0], zoom_start = 1.5)

folium.Choropleth(
    geo_data = geo_d, 
    data = df_esd,
    columns = ['end_station_name', 'count'],
    key_on = 'feature.properties.formal_en',
    fill_color = 'YlOrBr', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "End station popularity").add_to(end_station_map)
folium.LayerControl().add_to(end_station_map)

# %%
end_station_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
